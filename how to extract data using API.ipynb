# %%
import requests
import pandas as pd

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=acdd8f615abb6059750149212fc59da7&language=en-US&page=1').json()

# %%
response
# Out:
# {'page': 1,
#  'total_results': 10000,
#  'total_pages': 500,
#  'results': [{'popularity': 462.659,
#    'vote_count': 2853,
#    'video': False,
#    'poster_path': '/xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg',
#    'id': 419704,
#    'adult': False,
#    'backdrop_path': '/5BwqwxMEjeFtdknRV792Svo0K1v.jpg',
#    'original_language': 'en',
#    'original_title': 'Ad Astra',
#    'genre_ids': [18, 878],
#    'title': 'Ad Astra',
#    'vote_average': 5.9,
#    'overview': 'The near future, a time when both hope and hardships drive humanity to look to the stars and beyond. While a mysterious phenomenon menaces to destroy life on planet Earth, astronaut Roy McBride undertakes a mission across the immensity of space and its many perils to uncover the truth about a lost expedition that decades before boldly faced emptiness and silence in search of the unknown.',
#    'release_date': '2019-09-17'},
#   {'popularity': 223.823,
#    'vote_count': 13611,
#    'video': False,
# ...

# %%
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]

for i in response['results']:
    
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['vote_average'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])
    
d={'title':title, 'overview':overview, 'original_language':original_language, 'release_date':release_date,'popularity':popularity,'vote_count':vote_count,'vote_average':vote_average}
    
df=pd.DataFrame(d)

# %%
df
# Out:
#                                                 title  \
# 0                                            Ad Astra
# 1                                             Ant-Man
# 2                                   Bad Boys for Life
# 3                                           Bloodshot
# 4                          The Twilight Saga: Eclipse
# 5   Birds of Prey (and the Fantabulous Emancipatio...
# 6                                        Blood Father
# 7                                          Underwater
# 8                             Jumanji: The Next Level
# 9                                        The Platform
# 10                                             Onward
# 11                      Transformers: The Last Knight
# 12                                 Sonic the Hedgehog
# 13                        30 Days of Night: Dark Days
# 14                   Star Wars: The Rise of Skywalker
# 15                                  The Invisible Man
# ...

# %%
final=pd.DataFrame()
for j in range(1,501):
    
    response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=acdd8f615abb6059750149212fc59da7&language=en-US&page={}'.format(j)).json()
    
    popularity=[]
    vote_count=[]
    original_language=[]
    title=[]
    vote_average=[]
    overview=[]
    release_date=[]
    
    for i in response['results']:
        
        try:      
            popularity.append(i['popularity'])
        except:
            popularity.append('NaN')
        try:
            vote_count.append(i['vote_count'])
        except:
            vote_count.append('NaN')
        try:
            original_language.append(i['original_language'])
        except:
            original_language.append('NaN')
        try:
            title.append(i['title'])
        except:
            title.append('NaN')
        try:
            vote_average.append(i['vote_average'])
        except:
            vote_average.append('NaN')
        try:
            overview.append(i['overview'])
        except:
            overview.append('NaN')
        try:
            release_date.append(i['release_date'])
        except:
            release_date.append('NaN')
            
            
    

    d={'title':title, 'overview':overview, 'original_language':original_language, 'release_date':release_date,'popularity':popularity,'vote_count':vote_count,'vote_average':vote_average}

    df=pd.DataFrame(d)
    
    final=final.append(df, ignore_index=True)

# %%
final
# Out:
#                            title  \
# 0                       Ad Astra
# 1                        Ant-Man
# 2              Bad Boys for Life
# 3                      Bloodshot
# 4     The Twilight Saga: Eclipse
# ...                          ...
# 9995               The Last Face
# 9996             Too Big to Fail
# 9997                The Hard Way
# 9998                  Wonderland
# 9999                        Pink
#
#                                                overview original_language  \
# 0     The near future, a time when both hope and har...                en
# 1     Armed with the astonishing ability to shrink i...                en
# 2     Marcus and Mike are forced to confront new thr...                en
# 3     After he and his wife are murdered, marine Ray...                en
# 4     Bella once again finds herself surrounded by d...                en
# ...                                                 ...               ...
# ...

# %%
final.to_csv('Movies.csv')
