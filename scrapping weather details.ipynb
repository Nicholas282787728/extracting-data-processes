# %%
import numpy as np
import pandas as pd
import requests
import bs4

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://www.google.com/search?client=opera&hs=jVr&sxsrf=ALeKk01MtggtRgDqlw-iH-ANt8J04MKe_w%3A1593574146899&ei=AgP8XtzMNsK48QO7woyQBQ&q=weather+report&oq=weather+details&gs_lcp=CgZwc3ktYWIQARgAMgQIABBHMgQIABBHMgQIABBHMgQIABBHMgQIABBHMgQIABBHMgQIABBHMgQIABBHUABYAGChouQEaABwAXgAgAEAiAEAkgEAmAEAqgEHZ3dzLXdpeg&sclient=psy-ab',headers=headers).text

# %%
soup = bs4.BeautifulSoup(webpage, 'html.parser')

# %%
#print(soup.prettify())

# %%
box=soup.find('div', class_='vk_c card-section')

# %%
box
# Out:
# <div class="vk_c card-section" id="wob_wc"><span aria-level="3" role="heading"><div class="vk_gy vk_h" id="wob_loc">Kolkata, West Bengal</div><div class="vk_gy vk_sh" id="wob_dts">Wednesday, 11:00 am</div><div id="wob_dcp"><span class="vk_gy vk_sh" id="wob_dc">Haze</span></div></span><div id="wob_d" style="font:16px arial,helvetica,sans-serif;padding:20px 0 0;-webkit-touch-callout:none;-webkit-user-select:none"><div><img alt="Haze" id="wob_tci" src="//ssl.gstatic.com/onebox/weather/64/fog.png" style="float:left;height:64px;width:64px"/><div aria-level="3" role="heading" style="padding-left:10px;float:left"><div><div class="vk_bk sol-tmp" style="float:left;margin-top:-3px;font-size:64px"><span class="wob_t" id="wob_tm" style="display:inline">34</span><span class="wob_t" id="wob_ttm" style="display:none">94</span></div><div class="vk_bk wob-unit" style="float:left;font-size:16px;margin-top:6px"><span aria-disabled="true" aria-label="°Celsius" class="wob_t" role="button" style="display:
# ...

# %%
place=box.find('div', class_='vk_gy vk_h').text.strip()

# %%
place
# Out:
# 'Kolkata, West Bengal'

# %%
date_time=box.find('div', class_='vk_gy vk_sh').text.strip()

# %%
date_time
# Out:
# 'Wednesday, 11:00 am'

# %%
condition=box.find('span', class_='vk_gy vk_sh').text.strip()

# %%
condition
# Out:
# 'Haze'

# %%
temp_in_c=box.find('span', class_='wob_t').text.strip()

# %%
temp_in_f=box.find('span', id='wob_ttm').text.strip()

# %%
sub_box=box.find('div', class_='vk_gy vk_sh wob-dtl')

# %%
Precipitation=sub_box.find('span', id='wob_pp').text

# %%
Humidity=sub_box.find('span', id='wob_hm').text

# %%
wind=sub_box.find('span', id='wob_ws').text

# %%
Precipitation
# Out:
# '19%'

# %%
Humidity
# Out:
# '72%'

# %%
wind
# Out:
# '13 km/h'

# %%
#weather details

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://www.google.com/search?client=opera&hs=jVr&sxsrf=ALeKk01MtggtRgDqlw-iH-ANt8J04MKe_w%3A1593574146899&ei=AgP8XtzMNsK48QO7woyQBQ&q=weather+report&oq=weather+details&gs_lcp=CgZwc3ktYWIQARgAMgQIABBHMgQIABBHMgQIABBHMgQIABBHMgQIABBHMgQIABBHMgQIABBHMgQIABBHUABYAGChouQEaABwAXgAgAEAiAEAkgEAmAEAqgEHZ3dzLXdpeg&sclient=psy-ab',headers=headers).text

soup = bs4.BeautifulSoup(webpage, 'html.parser')
box=soup.find('div', class_='vk_c card-section')
place=box.find('div', class_='vk_gy vk_h').text.strip()
date_time=box.find('div', class_='vk_gy vk_sh').text.strip()
condition=box.find('span', class_='vk_gy vk_sh').text.strip()
temp_in_c=box.find('span', class_='wob_t').text.strip()
temp_in_f=box.find('span', id='wob_ttm').text.strip()
sub_box=box.find('div', class_='vk_gy vk_sh wob-dtl')
Precipitation=sub_box.find('span', id='wob_pp').text.strip()
Humidity=sub_box.find('span', id='wob_hm').text.strip()
wind=sub_box.find('span', id='wob_ws').text.strip()
